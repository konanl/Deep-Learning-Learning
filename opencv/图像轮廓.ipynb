# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 查找轮廓

# %%
img = cv2.imread('./fig/Jennie.png')

# %%
plt.imshow(img)

# %%
# 二值化
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
thresh, binary = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)

plt.imshow(binary)

# %%
# 查找轮廓
contours, hierarchy = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %%
hierarchy
# Out:
# array([[[   1,   -1,   -1,   -1],
#         [   2,    0,   -1,   -1],
#         [   3,    1,   -1,   -1],
#         ...,
#         [2261, 2259,   -1, 2244],
#         [2262, 2260,   -1, 2244],
#         [  -1, 2261,   -1, 2244]]], dtype=int32)

# %% [markdown]
# ## 绘制轮廓

# %%
img_copy = img.copy()
cv2.drawContours(img_copy, contours, -1, (0, 0, 255), 2)

plt.imshow(np.hstack((img, img_copy)))

# %%
# cv2.imshow('img', np.hstack((img, img_copy)))

# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# ## 轮廓的面积和周长

# %%
# 计算轮廓面积
area = cv2.contourArea(contours[121])
print(area)

# 计算周长
perimeter = cv2.arcLength(contours[121], closed=False)
print(perimeter)
# Out:
# 0.0
# 1.0

# %% [markdown]
# ## 多边形逼近

# %%
approx = cv2.approxPolyDP(contours[1090], 50, closed=True)

aa = cv2.drawContours(img_copy, [approx], 0, (0, 0, 255), 2)

# %%
plt.imshow(aa)

# %%
# cv2.imshow('img', np.hstack((img_copy, aa)))

# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# ## 凸包

# %%
hull = cv2.convexHull(contours[2261])
bb = cv2.drawContours(img, [hull], 0, (0, 0, 255), 2)

# %%
plt.imshow(bb)
